# %% [markdown]
# # **Step 01.Installing and Configuring Required Libraries**

# %%
#!pip install -q -U google-generativeai

# %%
import os

os.environ['GEMINI_API_KEY'] = 'your_actual_key_here'

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import Markdown, display

def to_markdown(text):
  text = text.replace('.', '*')
  return Markdown(textwrap.indent(text, '>',predicate=lambda line, _: True))
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
for m in genai.list_models():
  if 'generatContent' in m.supported_generation_methods:
    print(m.name)

# %%
for m in genai.list_models():
  print(m)
# Out:
# Model(name='models/gemini-2.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 2.5 Flash',
#       description=('Stable version of Gemini 2.5 Flash, our mid-size multimodal model that '
#                    'supports up to 1 million tokens, released in June of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent',
#                                     'countTokens',
#                                     'createCachedContent',
#                                     'batchGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.5-pro',
#       base_model_id='',
#       version='2.5',
#       display_name='Gemini 2.5 Pro',
#       description='Stable release (June 17th, 2025) of Gemini 2.5 Pro',
#       input_token_limit=1048576,
#       output_token_limit=65536,
# ...

# %% [markdown]
# # Step 02: Text Generation (First Project) Using GEMINI 3.0 FLASH

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response = model.generate_content('create table for ai vs gen ai vs agentic ai vs mcp')

# %%
print(response.text)
# Out:
# This table breaks down the differences between the broader field of AI, the creative capabilities of Generative AI, the autonomous nature of Agentic AI, and the technical standard of MCP (Model Context Protocol).
#
# ### Comparison Table: AI vs. Gen AI vs. Agentic AI vs. MCP
#
# | Feature | **Artificial Intelligence (AI)** | **Generative AI (Gen AI)** | **Agentic AI (AI Agents)** | **MCP (Model Context Protocol)** |
# | :--- | :--- | :--- | :--- | :--- |
# | **Core Definition** | The broad field of creating systems that simulate human intelligence. | A subset of AI focused on creating **new content** (text, images, code). | Systems that use LLMs to **act, plan, and use tools** to achieve goals. | An open **standard/protocol** for connecting AI models to data and tools. |
# ...

# %% [markdown]
# #2nd Project -Image Genrate Model Using Gemini 3

# %%
import PIL.Image

img = PIL.Image.open('/content/fish.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=239x148>

# %%
from IPython.display import Markdown

response = model.generate_content(img)

Markdown(response.text)
# Out:
# The fish in the image is an **Electric Blue Acara** (*Andinoacara pulcher*).
#
# It is a popular freshwater aquarium fish known for its striking, vibrant blue coloration and relatively peaceful temperament compared to many other cichlids.
#
# Key features visible in the image include:
# *   **Electric blue body:** The scales have a brilliant, iridescent blue hue.
# *   **Orange fin tips:** The dorsal (top) and caudal (tail) fins are often edged with a bright orange or yellowish border.
# *   **Stocky body shape:** It has the typical robust, oval-shaped body characteristic of the Acara genus.
